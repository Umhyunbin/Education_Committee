# %%
import pandas as pd
import os

# %%
original = pd.read_csv("서울특별시의회 회의록 제303회[정례회](2021.11.01 ~ 2021.12.27).csv", encoding = 'euc-kr')
original
# Out:
#             회의록구분  대수    회의구분    위원회                                   회수  \
# 0     서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 1     서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 2     서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 3     서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 4     서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# ...           ...  ..     ...    ...                                  ...
# 6035  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 6036  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 6037  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 6038  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 6039  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
#
#                                                   피감사기관            회의일자  \
# 0     서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 1     서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 2     서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 3     서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 4     서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# ...                                                 ...             ...
# 6035                                         서울시교육청(종합)  2021.11.12 금요일
# 6036                                         서울시교육청(종합)  2021.11.12 금요일
# 6037                                         서울시교육청(종합)  2021.11.12 금요일
# 6038                                         서울시교육청(종합)  2021.11.12 금요일
# 6039                                         서울시교육청(종합)  2021.11.12 금요일
#
#            발언자  발언순번                                               발언내용  기관구분
# 0      위원장 최기찬     1  다음으로 지방자치법 제41조와 같은 법 시행령 제39조부터 제50조까지 그리고 서울...   위원장
# 1     부교육감 김규태     2  선서! 본인은 서울특별시의회가 지방자치법 제41조의 규정에 의하여 소관 업무에 대한...  부교육감
# 2      위원장 최기찬     3  모두 자리에 앉아 주시기 바랍니다. 그러면 오늘 감사일정 안내드리겠습니다. 오늘은 ...   위원장
# 3     부교육감 김규태     4  안녕하십니까? 서울특별시 부교육감 김규태입니다. 바쁜 의정활동에도 불구하고 서울교육...  부교육감
# 4      위원장 최기찬     5  김규태 부교육감님 수고하셨습니다. 다음은 집행부로부터 업무보고를 받을 순서이나 원활...   위원장
# ...        ...   ...                                                ...   ...
# 6035    권순선 위원   247  그렇죠. 교장 선생님들이 좀 더 자유로워지셨으면 좋겠습니다. 그래서 여러 의견들을 ...    위원
# 6036  부교육감 김규태   248                                             알겠습니다.  부교육감
# 6037    권순선 위원   249  부교육감님의 강력한 어떤 실천, 여기 계신 많은 분들의 도움 이런 것들이 필요하지 ...    위원
# 6038  부교육감 김규태   250                                      명심하고 실천하겠습니다.  부교육감
# 6039  부위원장 전병주   251  권순선 위원님 수고하셨습니다. 이상으로 서울시교육청 소관 사무에 대한 질의와 답변을...  부위원장
#
# [6040 rows x 11 columns]

# %%
loc = os.getcwd()
join_dir = os.path.join(loc, "질문답변자 조인")
train = pd.read_excel(os.path.join(join_dir, "train.xlsx"))
train
# Out:
#                                                   발언내용  감정
# 0    본 위원 제 지역에도 그린스마트 미래학교로 지정된 학교가 있었습니다만, 물론 저게 ...   0
# 1    통상적인 사업들과 그린스마트 미래학교하고의 사회적, 언론적 파급효과가 이 정도일 것...   0
# 2    제가 알고 있기로는 각 부서에서 포상에 관해서는 자기 업무 관련해서 지정이 되어 있...   1
# 3    저희 나름대로는 공정하게 판단하려고 하고 있습니다, 이 부분에 대해서는요. 증거나 ...   2
# 4                     아침에 행감 준비로 신문을 못 보고 왔습니다. 죄송합니다.   0
# ..                                                 ...  ..
# 250  의석을 정돈해 주시기 바랍니다. 감사를 속개하겠습니다. (의사봉 3타) 오전에 이어...   1
# 251  양민규 위원님 수고하셨습니다. 또 추가 질의하실 위원님 계십니까? (「없습니다.」하...   1
# 252                                          네, 안녕하세요?   1
# 253                                          네, 그렇습니다.   1
# 254                                          네, 알겠습니다.   1
#
# [255 rows x 2 columns]

# %%
test = pd.read_csv(os.path.join(join_dir, "2021_감정분석_test_ver2.csv"), encoding = 'euc-kr')
test
# Out:
#                                                    발언내용  감정
# 0     의석을 정돈해 주시기 바랍니다. 존경하는 위원님 여러분 반갑습니다. 연일 계속되는 ...  중립
# 1     의석을 정돈해 주시기 바랍니다. 존경하는 위원님 여러분, 반갑습니다. 연일 계속되는...  중립
# 2     의석을 정돈해 주시기 바랍니다. 존경하고 사랑하는 우리 교육위원회 위원님 여러분, ...  긍정
# 3     의석을 정돈해 주시기 바랍니다. 존경하는 위원님 여러분, 반갑습니다. 연일 계속되는...  중립
# 4     의석을 정돈해 주시기 바랍니다. 존경하는 위원님 여러분, 연일 계속되는 행정사무감사...  긍정
# ...                                                 ...  ..
# 5783                      일단 정원은 경력이냐 신규냐 관계없이 받은 거고…….  중립
# 5784                                 별도로 진행을 해야 된다 이거죠?  중립
# 5785                                       열심히 노력하겠습니다.  긍정
# 5786                                       위원장님, 이상입니다.  중립
# 5787  수고 많이 하셨습니다. 황인구 위원님 질의 끝나셨고 추가질의하실 위원님들 계십니까?...  중립
#
# [5788 rows x 2 columns]

# %%
train_test = pd.concat([train, test])
train_test
# Out:
#                                                    발언내용  감정
# 0     본 위원 제 지역에도 그린스마트 미래학교로 지정된 학교가 있었습니다만, 물론 저게 ...   0
# 1     통상적인 사업들과 그린스마트 미래학교하고의 사회적, 언론적 파급효과가 이 정도일 것...   0
# 2     제가 알고 있기로는 각 부서에서 포상에 관해서는 자기 업무 관련해서 지정이 되어 있...   1
# 3     저희 나름대로는 공정하게 판단하려고 하고 있습니다, 이 부분에 대해서는요. 증거나 ...   2
# 4                      아침에 행감 준비로 신문을 못 보고 왔습니다. 죄송합니다.   0
# ...                                                 ...  ..
# 5783                      일단 정원은 경력이냐 신규냐 관계없이 받은 거고…….  중립
# 5784                                 별도로 진행을 해야 된다 이거죠?  중립
# 5785                                       열심히 노력하겠습니다.  긍정
# 5786                                       위원장님, 이상입니다.  중립
# 5787  수고 많이 하셨습니다. 황인구 위원님 질의 끝나셨고 추가질의하실 위원님들 계십니까?...  중립
#
# [6043 rows x 2 columns]

# %%
# 발언 내용이 unique key의 역할을 할 수 없지만, 다른 key를 추출할 수 없어 병합 후 중복 제거하는 방식으로 진행.
# 회의일자, 발언 순번을 key로 이용하는 방식으로 보완 가능. 
result = pd.merge(original, train_test, how = 'left', on = ['발언내용'])
result
# Out:
#               회의록구분  대수    회의구분    위원회                                   회수  \
# 0       서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 1       서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 2       서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 3       서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 4       서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# ...             ...  ..     ...    ...                                  ...
# 185463  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 185464  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 185465  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 185466  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 185467  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
#
#                                                     피감사기관            회의일자  \
# 0       서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 1       서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 2       서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 3       서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 4       서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# ...                                                   ...             ...
# 185463                                         서울시교육청(종합)  2021.11.12 금요일
# 185464                                         서울시교육청(종합)  2021.11.12 금요일
# 185465                                         서울시교육청(종합)  2021.11.12 금요일
# 185466                                         서울시교육청(종합)  2021.11.12 금요일
# 185467                                         서울시교육청(종합)  2021.11.12 금요일
#
#              발언자  발언순번                                               발언내용  \
# 0        위원장 최기찬     1  다음으로 지방자치법 제41조와 같은 법 시행령 제39조부터 제50조까지 그리고 서울...
# 1       부교육감 김규태     2  선서! 본인은 서울특별시의회가 지방자치법 제41조의 규정에 의하여 소관 업무에 대한...
# 2        위원장 최기찬     3  모두 자리에 앉아 주시기 바랍니다. 그러면 오늘 감사일정 안내드리겠습니다. 오늘은 ...
# 3       부교육감 김규태     4  안녕하십니까? 서울특별시 부교육감 김규태입니다. 바쁜 의정활동에도 불구하고 서울교육...
# 4        위원장 최기찬     5  김규태 부교육감님 수고하셨습니다. 다음은 집행부로부터 업무보고를 받을 순서이나 원활...
# ...          ...   ...                                                ...
# 185463  부교육감 김규태   248                                             알겠습니다.
# 185464  부교육감 김규태   248                                             알겠습니다.
# 185465    권순선 위원   249  부교육감님의 강력한 어떤 실천, 여기 계신 많은 분들의 도움 이런 것들이 필요하지 ...
# 185466  부교육감 김규태   250                                      명심하고 실천하겠습니다.
# 185467  부위원장 전병주   251  권순선 위원님 수고하셨습니다. 이상으로 서울시교육청 소관 사무에 대한 질의와 답변을...
#
#         기관구분   감정
# 0        위원장    1
# 1       부교육감    1
# 2        위원장  NaN
# 3       부교육감    1
# 4        위원장    1
# ...      ...  ...
# 185463  부교육감   중립
# 185464  부교육감   중립
# 185465    위원   긍정
# 185466  부교육감   긍정
# 185467  부위원장   중립
#
# [185468 rows x 12 columns]

# %%
result.to_csv("2021감성분석_중복제거.csv", encoding = 'euc-kr')

# %%
result['flag'] = True
result
# Out:
#               회의록구분  대수    회의구분    위원회                                   회수  \
# 0       서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 1       서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 2       서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 3       서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 4       서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# ...             ...  ..     ...    ...                                  ...
# 185463  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 185464  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 185465  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 185466  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 185467  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
#
#                                                     피감사기관            회의일자  \
# 0       서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 1       서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 2       서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 3       서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 4       서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# ...                                                   ...             ...
# 185463                                         서울시교육청(종합)  2021.11.12 금요일
# 185464                                         서울시교육청(종합)  2021.11.12 금요일
# 185465                                         서울시교육청(종합)  2021.11.12 금요일
# 185466                                         서울시교육청(종합)  2021.11.12 금요일
# 185467                                         서울시교육청(종합)  2021.11.12 금요일
#
#              발언자  발언순번                                               발언내용  \
# 0        위원장 최기찬     1  다음으로 지방자치법 제41조와 같은 법 시행령 제39조부터 제50조까지 그리고 서울...
# 1       부교육감 김규태     2  선서! 본인은 서울특별시의회가 지방자치법 제41조의 규정에 의하여 소관 업무에 대한...
# 2        위원장 최기찬     3  모두 자리에 앉아 주시기 바랍니다. 그러면 오늘 감사일정 안내드리겠습니다. 오늘은 ...
# 3       부교육감 김규태     4  안녕하십니까? 서울특별시 부교육감 김규태입니다. 바쁜 의정활동에도 불구하고 서울교육...
# 4        위원장 최기찬     5  김규태 부교육감님 수고하셨습니다. 다음은 집행부로부터 업무보고를 받을 순서이나 원활...
# ...          ...   ...                                                ...
# 185463  부교육감 김규태   248                                             알겠습니다.
# 185464  부교육감 김규태   248                                             알겠습니다.
# 185465    권순선 위원   249  부교육감님의 강력한 어떤 실천, 여기 계신 많은 분들의 도움 이런 것들이 필요하지 ...
# 185466  부교육감 김규태   250                                      명심하고 실천하겠습니다.
# 185467  부위원장 전병주   251  권순선 위원님 수고하셨습니다. 이상으로 서울시교육청 소관 사무에 대한 질의와 답변을...
#
#         기관구분   감정  flag
# 0        위원장    1  True
# 1       부교육감    1  True
# 2        위원장  NaN  True
# 3       부교육감    1  True
# 4        위원장    1  True
# ...      ...  ...   ...
# 185463  부교육감   중립  True
# 185464  부교육감   중립  True
# 185465    위원   긍정  True
# 185466  부교육감   긍정  True
# 185467  부위원장   중립  True
#
# [185468 rows x 13 columns]

# %%
for i in range(1, len(result)):
    if (result.iloc[i - 1, 6] == result.iloc[i, 6]) & (result.iloc[i - 1, 8] == result.iloc[i, 8]):
        result.iloc[i, 12] = False
result_final = result[result['flag']]
result_final
# Out:
#               회의록구분  대수    회의구분    위원회                                   회수  \
# 0       서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 1       서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 2       서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 3       서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 4       서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# ...             ...  ..     ...    ...                                  ...
# 185434  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 185435  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 185465  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 185466  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 185467  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
#
#                                                     피감사기관            회의일자  \
# 0       서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 1       서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 2       서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 3       서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 4       서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# ...                                                   ...             ...
# 185434                                         서울시교육청(종합)  2021.11.12 금요일
# 185435                                         서울시교육청(종합)  2021.11.12 금요일
# 185465                                         서울시교육청(종합)  2021.11.12 금요일
# 185466                                         서울시교육청(종합)  2021.11.12 금요일
# 185467                                         서울시교육청(종합)  2021.11.12 금요일
#
#              발언자  발언순번                                               발언내용  \
# 0        위원장 최기찬     1  다음으로 지방자치법 제41조와 같은 법 시행령 제39조부터 제50조까지 그리고 서울...
# 1       부교육감 김규태     2  선서! 본인은 서울특별시의회가 지방자치법 제41조의 규정에 의하여 소관 업무에 대한...
# 2        위원장 최기찬     3  모두 자리에 앉아 주시기 바랍니다. 그러면 오늘 감사일정 안내드리겠습니다. 오늘은 ...
# 3       부교육감 김규태     4  안녕하십니까? 서울특별시 부교육감 김규태입니다. 바쁜 의정활동에도 불구하고 서울교육...
# 4        위원장 최기찬     5  김규태 부교육감님 수고하셨습니다. 다음은 집행부로부터 업무보고를 받을 순서이나 원활...
# ...          ...   ...                                                ...
# 185434    권순선 위원   247  그렇죠. 교장 선생님들이 좀 더 자유로워지셨으면 좋겠습니다. 그래서 여러 의견들을 ...
# 185435  부교육감 김규태   248                                             알겠습니다.
# 185465    권순선 위원   249  부교육감님의 강력한 어떤 실천, 여기 계신 많은 분들의 도움 이런 것들이 필요하지 ...
# 185466  부교육감 김규태   250                                      명심하고 실천하겠습니다.
# 185467  부위원장 전병주   251  권순선 위원님 수고하셨습니다. 이상으로 서울시교육청 소관 사무에 대한 질의와 답변을...
#
#         기관구분   감정  flag
# 0        위원장    1  True
# 1       부교육감    1  True
# 2        위원장  NaN  True
# 3       부교육감    1  True
# 4        위원장    1  True
# ...      ...  ...   ...
# 185434    위원   긍정  True
# 185435  부교육감   중립  True
# 185465    위원   긍정  True
# 185466  부교육감   긍정  True
# 185467  부위원장   중립  True
#
# [6040 rows x 13 columns]

# %%
result_final.to_csv("2021_감성분석_최종.csv", index = False, encoding = 'euc-kr')

# %%
# 학습 데이터 셋 선정을 위한 결과 비교

# %%
result_part = pd.read_csv(os.path.join(join_dir, "2020_감정분석_test.csv"), encoding = "euc-kr")
result_all = pd.read_csv(os.path.join(join_dir, "2020_감정분석_test_all_ver.csv"), encoding = "euc-kr")

# %%
diff = []
for i in range(len(result_part)):
    if result_part.iloc[i, 1] != result_all.iloc[i, 1]:
        diff.append([result_part.iloc[i, 0], result_part.iloc[i, 1], result_all.iloc[i, 1]])
diff_df = pd.DataFrame(diff, columns = ['발언내용', '2021일부', '2021전체'])
diff_df.to_csv(os.path.join(join_dir, "2020 학습결과 비교.csv"), index = False, encoding = 'euc-kr')

# %%
result_final = pd.read_csv("2021_감성분석_통합본.csv", encoding = 'euc-kr')
result_final
# Out:
#             회의록구분  대수    회의구분    위원회                                   회수  \
# 0     서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 1     서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 2     서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 3     서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 4     서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# ...           ...  ..     ...    ...                                  ...
# 6035  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 6036  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 6037  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 6038  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
# 6039  서울특별시의회 회의록  10  행정사무감사  교육위원회  제303회[정례회](2021.11.01 ~ 2021.12.27)
#
#                                                   피감사기관            회의일자  \
# 0     서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 1     서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 2     서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 3     서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# 4     서울시교육청 대변인, 감사관, 총무과, 기획조정실, 11개 교육지원청, 교육연구정보...  2021.11.02 화요일
# ...                                                 ...             ...
# 6035                                         서울시교육청(종합)  2021.11.12 금요일
# 6036                                         서울시교육청(종합)  2021.11.12 금요일
# 6037                                         서울시교육청(종합)  2021.11.12 금요일
# 6038                                         서울시교육청(종합)  2021.11.12 금요일
# 6039                                         서울시교육청(종합)  2021.11.12 금요일
#
#            발언자  발언순번                                               발언내용  기관구분  \
# 0      위원장 최기찬     1  다음으로 지방자치법 제41조와 같은 법 시행령 제39조부터 제50조까지 그리고 서울...   위원장
# 1     부교육감 김규태     2  선서! 본인은 서울특별시의회가 지방자치법 제41조의 규정에 의하여 소관 업무에 대한...  부교육감
# 2      위원장 최기찬     3  모두 자리에 앉아 주시기 바랍니다. 그러면 오늘 감사일정 안내드리겠습니다. 오늘은 ...   위원장
# 3     부교육감 김규태     4  안녕하십니까? 서울특별시 부교육감 김규태입니다. 바쁜 의정활동에도 불구하고 서울교육...  부교육감
# 4      위원장 최기찬     5  김규태 부교육감님 수고하셨습니다. 다음은 집행부로부터 업무보고를 받을 순서이나 원활...   위원장
# ...        ...   ...                                                ...   ...
# 6035    권순선 위원   247  그렇죠. 교장 선생님들이 좀 더 자유로워지셨으면 좋겠습니다. 그래서 여러 의견들을 ...    위원
# 6036  부교육감 김규태   248                                             알겠습니다.  부교육감
# 6037    권순선 위원   249  부교육감님의 강력한 어떤 실천, 여기 계신 많은 분들의 도움 이런 것들이 필요하지 ...    위원
# 6038  부교육감 김규태   250                                      명심하고 실천하겠습니다.  부교육감
# 6039  부위원장 전병주   251  권순선 위원님 수고하셨습니다. 이상으로 서울시교육청 소관 사무에 대한 질의와 답변을...  부위원장
#
#       감정
# 0     중립
# 1     중립
# 2     중립
# 3     중립
# 4     중립
# ...   ..
# 6035  긍정
# 6036  중립
# 6037  긍정
# 6038  긍정
# 6039  중립
#
# [6040 rows x 12 columns]

# %%
person = list(result_final['발언자'].unique())
person
# Out:
# ['위원장 최기찬',
#  '부교육감 김규태',
#  '황인구 위원',
#  '이석주 위원',
#  '감사관 이민종',
#  '이동현 위원',
#  '총무과장 최웅장',
#  '이호대 위원',
#  '대변인 성현석',
#  '기획조정실장 최승복',
#  '김용연 위원',
#  '권순선 위원',
#  '부위원장 김용연',
#  '김생환 위원',
#  '부위원장 전병주',
#  '김수규 위원',
#  '동부교육지원청장 서경수',
#  '양민규 위원',
#  '문영민 위원',
#  '교육연구정보원장 백미원',
#  '김상진 위원',
#  '강남서초교육지원청장 조영상',
#  '전병주 위원',
#  '정책ㆍ안전기획관 한만중',
#  '교육정책국장 고효선',
#  '교육연수원장 송형세',
#  '유아교육과장 오필순',
#  '초등교육과장 강연실',
#  '중등교육과장 안윤호',
#  '유아교육진흥원장 강경숙',
#  '과학전시관장 김연배',
#  '평생진로교육국장 함혜성',
#  '학교보건진흥원장 임영식',
#  '학생체육관장 최선희',
#  '체육건강문화예술과장 오정훈',
#  '진로직업교육과장 이조복',
#  '민주시민생활교육과장 백해룡',
#  '정독도서관장 이길환',
#  '학생교육원장 이종탁',
#  '평생교육과장 김덕희',
#  '마포평생학습관장 김원식',
#  '강서도서관장 이명하',
#  '교육행정국장 이병호',
#  '학교지원과장 고영갑',
#  '교육시설안전과장 이용식',
#  '교육시설관리본부장 김재환',
#  '학교안전공제회이사장 김형배',
#  '교육재정과장 조성래',
#  '학교안정공제회사무국장 한창화']

# %%
d = []
for p in person:
    tmp = result_final[result_final['발언자'] == p]
    pos = len(tmp[tmp['감정'] == '긍정'])
    neu = len(tmp[tmp['감정'] == '중립'])
    neg = len(tmp[tmp['감정'] == '부정'])
    try:
        ratio = (pos / (pos + neg)) * 100
    except ZeroDivisionError:
        ratio = 0
    d.append([p, pos, neu, neg, ratio])
print(d)
# Out:
# [['위원장 최기찬', 8, 136, 3, 72.72727272727273], ['부교육감 김규태', 109, 401, 39, 73.64864864864865], ['황인구 위원', 78, 237, 93, 45.614035087719294], ['이석주 위원', 14, 100, 49, 22.22222222222222], ['감사관 이민종', 12, 57, 2, 85.71428571428571], ['이동현 위원', 29, 215, 118, 19.727891156462583], ['총무과장 최웅장', 8, 55, 1, 88.88888888888889], ['이호대 위원', 40, 192, 113, 26.143790849673206], ['대변인 성현석', 4, 25, 0, 100.0], ['기획조정실장 최승복', 25, 145, 7, 78.125], ['김용연 위원', 26, 132, 60, 30.23255813953488], ['권순선 위원', 50, 196, 56, 47.16981132075472], ['부위원장 김용연', 3, 50, 10, 23.076923076923077], ['김생환 위원', 30, 100, 54, 35.714285714285715], ['부위원장 전병주', 7, 75, 8, 46.666666666666664], ['김수규 위원', 27, 76, 19, 58.69565217391305], ['동부교육지원청장 서경수', 2, 5, 0, 100.0], ['양민규 위원', 39, 171, 95, 29.1044776119403], ['문영민 위원', 24, 71, 129, 15.686274509803921], ['교육연구정보원장 백미원', 8, 21, 3, 72.72727272727273], ['김상진 위원', 20, 71, 53, 27.397260273972602], ['강남서초교육지원청장 조영상', 0, 1, 0, 0], ['전병주 위원', 14, 89, 30, 31.818181818181817], ['정책ㆍ안전기획관 한만중', 0, 9, 1, 0.0], ['교육정책국장 고효선', 51, 141, 7, 87.93103448275862], ['교육연수원장 송형세', 0, 3, 0, 0], ['유아교육과장 오필순', 17, 56, 2, 89.47368421052632], ['초등교육과장 강연실', 5, 10, 2, 71.42857142857143], ['중등교육과장 안윤호', 5, 5, 0, 100.0], ['유아교육진흥원장 강경숙', 3, 6, 0, 100.0], ['과학전시관장 김연배', 3, 7, 0, 100.0], ['평생진로교육국장 함혜성', 40, 240, 9, 81.63265306122449], ['학교보건진흥원장 임영식', 12, 105, 2, 85.71428571428571], ['학생체육관장 최선희', 3, 19, 0, 100.0], ['체육건강문화예술과장 오정훈', 18, 52, 2, 90.0], ['진로직업교육과장 이조복', 26, 38, 2, 92.85714285714286], ['민주시민생활교육과장 백해룡', 20, 54, 2, 90.9090909090909], ['정독도서관장 이길환', 1, 13, 2, 33.33333333333333], ['학생교육원장 이종탁', 0, 20, 0, 0], ['평생교육과장 김덕희', 3, 20, 1, 75.0], ['마포평생학습관장 김원식', 1, 3, 0, 100.0], ['강서도서관장 이명하', 1, 8, 1, 50.0], ['교육행정국장 이병호', 67, 448, 20, 77.01149425287356], ['학교지원과장 고영갑', 2, 43, 2, 50.0], ['교육시설안전과장 이용식', 3, 88, 1, 75.0], ['교육시설관리본부장 김재환', 1, 42, 1, 50.0], ['학교안전공제회이사장 김형배', 3, 51, 4, 42.857142857142854], ['교육재정과장 조성래', 7, 56, 2, 77.77777777777779], ['학교안정공제회사무국장 한창화', 0, 8, 0, 0]]

# %%
sent_ratio = pd.DataFrame(d, columns = ['발언자', '긍정', '중립', '부정', '감성지수'])
sent_ratio['감성지수'] = sent_ratio['감성지수'].apply(round)

# %%
sent_ratio.to_csv("2021_감성지수_산출_중립포함.csv", index = False, encoding = 'euc-kr')
# 중복 위원 있음.
